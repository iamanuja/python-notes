# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# goes to chrom and search content then open website that you want and copy that link
urlopen("https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g")

# %%
httpobject = urlopen("https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g")# this gives response
webdata = httpobject.read() # read http content and save that in variable webdata in binary format
print(webdata)  #
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
soupdata = soup(webdata)#convert data into soup data

# %%
type(soupdata)
# Out:
# bs4.BeautifulSoup

# %%
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'DEFAULT_INTERESTING_STRING_TYPES',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_decode_markup',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_markup_is_url',
#  '_markup_resembles_filename',
# ...

# %%
print(soupdata)
# Out:
# <!DOCTYPE html>
# ...

# %%
soupdata.findAll('div',{'class':'_2kHMtA'}) # lowest div tag that contain all container data => '_2kHMtA' <= this is class name of div tag ..thats why key is class
# gives op in list form .. all div tag sep by ,
# Out:
# [<div class="_2kHMtA"><div class="_2tfzpE"><span>Ad</span></div><a class="_1fQZEK" href="/primebook-4g-android-based-mediatek-mt8788-4-gb-64-gb-emmc-storage-prime-os-thin-light-laptop/p/itmecb7e931de990?pid=COMGH2NKYVZCVXAW&amp;lid=LSTCOMGH2NKYVZCVXAWAYX3II&amp;marketplace=FLIPKART&amp;store=6bo%2Fb5g&amp;srno=b_1_1&amp;otracker=browse&amp;fm=organic&amp;iid=en_VJfk3DHw6I-wpX8HTozHtec6VaVikC0shjhQMat-KzOiGyzYsU8lUzG2PaeiE7p_K78dJ8WDhmlJXloKmFaCLQ%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=ubecqsqzyo0000001689007825174" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Primebook 4G Android Based MediaTek MT8788 - (4 GB/64 GB EMMC Storage/Prime OS) 4G Thin and Light Lapt..." class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/computer/i/j/k/-original-imagzzsh3afavghf.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3
# ...

# %%
containers = soupdata.findAll('div',{'class':'_2kHMtA'})
print(type(containers),len(containers)) #  so above data is result set type and contains 24 div tags total
# Out:
# <class 'bs4.element.ResultSet'> 24

# %%
containers[0] # first div tag data
# Out:
# <div class="_2kHMtA"><div class="_2tfzpE"><span>Ad</span></div><a class="_1fQZEK" href="/primebook-4g-android-based-mediatek-mt8788-4-gb-64-gb-emmc-storage-prime-os-thin-light-laptop/p/itmecb7e931de990?pid=COMGH2NKYVZCVXAW&amp;lid=LSTCOMGH2NKYVZCVXAWAYX3II&amp;marketplace=FLIPKART&amp;store=6bo%2Fb5g&amp;srno=b_1_1&amp;otracker=browse&amp;fm=organic&amp;iid=en_VJfk3DHw6I-wpX8HTozHtec6VaVikC0shjhQMat-KzOiGyzYsU8lUzG2PaeiE7p_K78dJ8WDhmlJXloKmFaCLQ%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=ubecqsqzyo0000001689007825174" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Primebook 4G Android Based MediaTek MT8788 - (4 GB/64 GB EMMC Storage/Prime OS) 4G Thin and Light Lapt..." class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/computer/i/j/k/-original-imagzzsh3afavghf.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A
# ...

# %%
for i in containers:
    product=i.findAll('div',{'class':'_4rR01T'})
    print(product)
    break
# Out:
# [<div class="_4rR01T">Primebook 4G Android Based MediaTek MT8788 - (4 GB/64 GB EMMC Storage/Prime OS) 4G Thin and Light Lapt...</div>]

# %%
for i in containers:
    product=i.findAll('div',{'class':'_4rR01T'})
    print(product[0])
    break
# product contains list,we want data thats why we used product[0] <= this extract data from list and gives whole data
# Out:
# <div class="_4rR01T">Primebook 4G Android Based MediaTek MT8788 - (4 GB/64 GB EMMC Storage/Prime OS) 4G Thin and Light Lapt...</div>

# %%
for i in containers:
    product=i.findAll('div',{'class':'_4rR01T'})
    print(product[0].text)
    break # cause just to see the result for first div tag
# product contains list,we want data thats why we used product[0] <= this extract data from list and gives whole data
# Out:
# Primebook 4G Android Based MediaTek MT8788 - (4 GB/64 GB EMMC Storage/Prime OS) 4G Thin and Light Lapt...

# %%
for i in containers:
    product=i.findAll('div',{'class':'_4rR01T'})
    print(product[0].text.split('-'))
    break
# Out:
# ['Primebook 4G Android Based MediaTek MT8788 ', ' (4 GB/64 GB EMMC Storage/Prime OS) 4G Thin and Light Lapt...']

# %%
for i in containers:
    product=i.findAll('div',{'class':'_4rR01T'})
    print(product[0].text.split('-')[0]) #o/p in list so we extract 0th index that content what we want
# Out:
# Primebook 4G Android Based MediaTek MT8788
# Primebook 4G Android Based MediaTek MT8788
# HP 15s (2023) Ryzen 3 Dual Core 3250U
# ASUS Vivobook 15 Core i3 11th Gen
# HP 15s (2023) Intel Core i3 12th Gen
# DELL Inspiron Core i3 11th Gen
# HP 14s Intel Core i3 11th Gen
# Primebook 4G Android Based MediaTek MT8788
# Lenovo Intel Celeron Dual Core
# realme Book (Slim) Core i3 11th Gen
# Lenovo IdeaPad Ryzen 5 Hexa Core 5500U
# Lenovo IdeaPad 3 Core i3 12th Gen
# ASUS Vivobook 15 Core i5 11th Gen
# HP 15s Intel Core i3 12th Gen
# Acer Extensa (2023) Core i3
# Infinix INBook X1 Neo Series Celeron Quad Core
# Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U
# Lenovo Ryzen 3 Quad Core 7320U
# Lenovo IdeaPad 3 Intel Core i3 11th Gen
# DELL Inspiron Core i5 11th Gen
# Lenovo IdeaPad 3 Core i3 11th Gen
# Lenovo IdeaPad Slim 3 Intel Core i3 12th Gen
# Acer One Core i3 11th Gen
# HP 15s (2023) Athlon Dual Core 3050U

# %% [markdown]
# #### // find – directly gives op without in list(op contains div and text) , only fetch 1st occurrence of that div and class … but there are so many div with same class name so avoid in that situation.
# #### // findAll – fetch all occurrences  and gives output in list form(op contains list , div and text) .

# %% [raw]
# # if u sure in whole page only 1 div tag present whose class name u know then you can use find method it gives o/p without list... OR u can say u want to extract data only from single container then also u can use this
#
# ######  only fetch 1st occurrence of that div and class

# %% [markdown]
# #https://www.youtube.com/watch?v=eMtMaUJ3rBw&list=PLPBPWin4aWklCQu9q2zLQmspH_GQtVDTe&index=2
# # 20:42 <= watch at

# %%
# example =>

# %%
for i in containers:
    product=i.find('div',{'class':'_4rR01T'})
    print(product)
    break
# Out:
# <div class="_4rR01T">Primebook 4G Android Based MediaTek MT8788 - (4 GB/64 GB EMMC Storage/Prime OS) 4G Thin and Light Lapt...</div>

# %%
for i in containers:
    product=i.find('div',{'class':'_4rR01T'})
    print(product.text.split('-')[0])
# Out:
# Primebook 4G Android Based MediaTek MT8788
# Primebook 4G Android Based MediaTek MT8788
# HP 15s (2023) Ryzen 3 Dual Core 3250U
# ASUS Vivobook 15 Core i3 11th Gen
# HP 15s (2023) Intel Core i3 12th Gen
# DELL Inspiron Core i3 11th Gen
# HP 14s Intel Core i3 11th Gen
# Primebook 4G Android Based MediaTek MT8788
# Lenovo Intel Celeron Dual Core
# realme Book (Slim) Core i3 11th Gen
# Lenovo IdeaPad Ryzen 5 Hexa Core 5500U
# Lenovo IdeaPad 3 Core i3 12th Gen
# ASUS Vivobook 15 Core i5 11th Gen
# HP 15s Intel Core i3 12th Gen
# Acer Extensa (2023) Core i3
# Infinix INBook X1 Neo Series Celeron Quad Core
# Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U
# Lenovo Ryzen 3 Quad Core 7320U
# Lenovo IdeaPad 3 Intel Core i3 11th Gen
# DELL Inspiron Core i5 11th Gen
# Lenovo IdeaPad 3 Core i3 11th Gen
# Lenovo IdeaPad Slim 3 Intel Core i3 12th Gen
# Acer One Core i3 11th Gen
# HP 15s (2023) Athlon Dual Core 3050U

# %%
# data contains strip at end

# %%
for i in containers:
    product=i.find('div',{'class':'_4rR01T'})
    print(product.text.split('-')[0].strip())
    break
# Out:
# Primebook 4G Android Based MediaTek MT8788

# %%
for i in containers:
    product=i.find('div',{'class':'_4rR01T'})
    productName = product.text.split('-')[0].strip()

# %%
for i in containers:
    stars=i.find('div',{'class':'_3LWZlK'})
    print(stars.text) # as here star is not given for 11 th product so try exception handling
# Out:
# 4
# 4
# 4.1
# 4.2
# 4.3
# 4.1
# 4.3
# 4
# 4.1
# 4.4
# 4.3
# 4.1
# 4.2
# 4.3
# 4.2
# 4.2
# 4.3
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 3
#       1 for i in containers:
#       2     stars=i.find('div',{'class':'_3LWZlK'})
# ----> 3     print(stars.text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
for i in containers:
    stars=i.find('div',{'class':'_3LWZlK'})
    try:
        print(stars.text)
    except:
        print(stars)
# Out:
# 4
# 4
# 4.1
# 4.2
# 4.3
# 4.1
# 4.3
# 4
# 4.1
# 4.4
# 4.3
# 4.1
# 4.2
# 4.3
# 4.2
# 4.2
# 4.3
# None
# 4.2
# 4
# 4.1
# 4.1
# 4.1
# 4

# %%
for i in containers:
    ratings = i.find('span',{'class':'_2_R_DZ'})
    try:
        print(ratings.text)
    except:
        print(ratings)
# Out:
# 1,022 Ratings & 326 Reviews
# 1,022 Ratings & 326 Reviews
# 1,586 Ratings & 152 Reviews
# 3,171 Ratings & 284 Reviews
# 123 Ratings & 12 Reviews
# 581 Ratings & 92 Reviews
# 3,067 Ratings & 261 Reviews
# 224 Ratings & 72 Reviews
# 1,496 Ratings & 151 Reviews
# 14,028 Ratings & 2,025 Reviews
# 2,095 Ratings & 218 Reviews
# 245 Ratings & 25 Reviews
# 1,745 Ratings & 140 Reviews
# 743 Ratings & 87 Reviews
# 117 Ratings & 17 Reviews
# 3,955 Ratings & 553 Reviews
# 2,095 Ratings & 218 Reviews
# None
# 5,458 Ratings & 501 Reviews
# 130 Ratings & 9 Reviews
# 99 Ratings & 9 Reviews
# 245 Ratings & 25 Reviews
# 225 Ratings & 23 Reviews
# 1,381 Ratings & 126 Reviews

# %%
import re # one or more no.s can comes,comma may or may not comes thats why *,after comma no can come or no
re.findall('\d+,*\d*', "2,058 Ratings & 0 Reviews") # d* <= this is for no may present or not
# Out:
# ['2,058', '0']

# %%
ratRev = re.findall('\d*,*\d+',"0 Ratings & 25 Reviews")
print(ratRev[0] , ratRev[1])
# Out:
# 0 25

# %%
for i in containers:
    rating = i.find('span',{'class':'_2_R_DZ'})
    try:
        ratRev = re.findall('\d*,*\d*',rating.text)
        Ratings=ratRev[0]
        Reviews=ratRev[1]
    except:
        Ratings=0
        Reviews=0
    print(Ratings,Reviews)
# Out:
# 1,022
# 1,022
# 1,586
# 3,171
# 123
# 581
# 3,067
# 224
# 1,496
# 14,028
# 2,095
# 245
# 1,745
# 743
# 117
# 3,955
# 2,095
# 0 0
# 5,458
# 130
# 99
# 245
# 225
# 1,381

# %%
for i in containers:
    currentPrice=i.find('div',{'class':'_30jeq3 _1_WHN1'})
    print(currentPrice.text)
# Out:
# ₹16,990
# ₹16,990
# ₹31,990
# ₹34,990
# ₹40,990
# ₹37,890
# ₹35,990
# ₹18,990
# ₹27,989
# ₹35,990
# ₹47,990
# ₹40,990
# ₹47,990
# ₹41,990
# ₹30,990
# ₹22,990
# ₹46,948
# ₹39,990
# ₹36,450
# ₹47,990
# ₹34,990
# ₹40,990
# ₹27,990
# ₹30,990

# %%
for i in containers:
    info=i.findAll('li',{'class':'rgWa7D'})
    Processor=info[0].text
    RAM_storage=info[1].text
    a=RAM_storage.split()
    Storage=" ".join(a[:2])
    RAM=" ".join(a[2:])
    print(Storage ,RAM)
    break
# Out:
# 4 GB LPDDR4 RAM

# %%
for i in containers:
    ImageURL=i.img
    print(ImageURL.get('src')) # get method => used to find particular key
    break
# Out:
# https://rukminim2.flixcart.com/image/312/312/xif0q/computer/i/j/k/-original-imagzzsh3afavghf.jpeg?q=70

# %%
for i in containers:
    Image=i.img
    ImageURL = ImageURL.get('src')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 3
#       1 for i in containers:
#       2     Image=i.img
# ----> 3     ImageURL = ImageURL.get('src')
#
# AttributeError: 'str' object has no attribute 'get'

# %% [markdown]
# ## combining all things

# %%
for i in containers:
    
    product=i.find('div',{'class':'_4rR01T'})
    productName = product.text.split('-')[0].strip() 
   
    stars=i.find('div',{'class':'_3LWZlK'})
    try:
        Stars = stars.text # storing stars data in Stars var
    except:
        Stars = 0
    
    rating = i.find('span',{'class':'_2_R_DZ'})
    try:
        ratRev = re.findall('\d*,*\d*',rating.text)
        Ratings=ratRev[0]
        Reviews=ratRev[1]
    except:
        Ratings=0
        Reviews=0
    
    CurrentPrice=i.find('div',{'class':'_3I9_wc _27UcVY'}).text
    
    mrp=i.find('div',{'class':''})
    try:
        MRP = mrp.text # storing 
    except:
        MRP = 0
        
    info=i.findAll('li',{'class':'rgWa7D'})
    Processor=info[0].text
    RAM_storage=info[1].text
    a=RAM_storage.split()
    Storage=" ".join(a[:2])
    RAM=" ".join(a[2:])
    
    Image=i.img
    ImageURL = Image.get('src')
    
    print(productName,Stars,Ratings,Reviews,CurrentPrice,MRP,Processor,RAM,Storage,ImageURL)
    print('\n')
# Out:
# Primebook 4G Android Based MediaTek MT8788 4 1,022  ₹24,990  MediaTek MediaTek MT8788 Processor LPDDR4 RAM 4 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/i/j/k/-original-imagzzsh3afavghf.jpeg?q=70
#
#
# Primebook 4G Android Based MediaTek MT8788 4 1,022  ₹24,990  MediaTek MediaTek MT8788 Processor LPDDR4 RAM 4 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/x/y/s/-original-imagn9s6z2qmxmem.jpeg?q=70
#
#
# HP 15s (2023) Ryzen 3 Dual Core 3250U 4.1 1,586  ₹39,995  AMD Ryzen 3 Dual Core Processor DDR4 RAM 8 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/5/6/i/-original-imaggshd5zgfe8ev.jpeg?q=70
#
#
# ASUS Vivobook 15 Core i3 11th Gen 4.2 3,171  ₹49,990  Intel Core i3 Processor (11th Gen) DDR4 RAM 8 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/q/e/z/-original-imagpxgqesgrthks.jpeg?q=70
#
#
# ...

# %% [markdown]
# ## creating file for this

# %% [markdown]
# #### add below code to above code

# %%
f=open('laptop_info1.csv','wb') # 
f.write('productName,Stars,Ratings,Reviews,CurrentPrice,MRP,Processor,RAM,Storage,ImageURL\n'.encode()) # this becomes col names  \n break line after 1 line

f.write(f"{productName},{Stars},{Ratings},{Reviews},{CurrentPrice},{MRP},{Processor},{RAM},{Storage},{ImageURL}".encode())

f.close() # out of loop

# %%
f=open('laptop_info1.csv','wb') # 
f.write('productName,Stars,Ratings,Reviews,CurrentPrice,MRP,Processor,RAM,Storage,ImageURL \n'.encode())
for i in containers:
    
    product=i.find('div',{'class':'_4rR01T'})
    productName = product.text.split('-')[0].strip() 
   
    star=i.find('div',{'class':'_3LWZlK'})
    try:
        Stars = star.text # storing stars data in Stars var
    except:
        Stars = 0
    
    rating = i.findAll('span',{'class':'_2_R_DZ'})
    try:
        ratRev = re.findall('\d+,*\d*',rating)
        Ratings=ratRev[0]
        Reviews=ratRev[1]
    except:
        Ratings=0
        Reviews=0
    
    CurrentPrice=i.find('div',{'class':'_3I9_wc _27UcVY'}).text.replace(',','').replace('₹','')
    
    mrp=i.find('div',{'class':''})
    try:
        MRP = mrp.text.replace(',','') # storing 
    except:
        MRP = 0
        
    info=i.findAll('li',{'class':'rgWa7D'})
    Processor=info[0].text
    RAM_storage=info[1].text.split()
    Storage=" ".join(RAM_storage[:2])
    RAM=" ".join(RAM_storage[2:])
    
    Image=i.img
    ImageURL = Image.get('src')
    
    print(productName,Stars,Ratings,Reviews,CurrentPrice,MRP,Processor,RAM,Storage,ImageURL)
    f.write(f"{productName},{Stars},{Ratings},{Reviews},{CurrentPrice},{MRP},{Processor},{RAM},{Storage},{ImageURL} \n ".encode()) # \n for going to next line in csv file
f.close()
# Out:
# Primebook 4G Android Based MediaTek MT8788 4 0 0 24990  MediaTek MediaTek MT8788 Processor LPDDR4 RAM 4 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/i/j/k/-original-imagzzsh3afavghf.jpeg?q=70
# Primebook 4G Android Based MediaTek MT8788 4 0 0 24990  MediaTek MediaTek MT8788 Processor LPDDR4 RAM 4 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/x/y/s/-original-imagn9s6z2qmxmem.jpeg?q=70
# HP 15s (2023) Ryzen 3 Dual Core 3250U 4.1 0 0 39995  AMD Ryzen 3 Dual Core Processor DDR4 RAM 8 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/5/6/i/-original-imaggshd5zgfe8ev.jpeg?q=70
# ASUS Vivobook 15 Core i3 11th Gen 4.2 0 0 49990  Intel Core i3 Processor (11th Gen) DDR4 RAM 8 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/q/e/z/-original-imagpxgqesgrthks.jpeg?q=70
# ...

# %%
import pandas as pd

# %% [markdown]
# # scrap all pages

# %%
soupdata <= contains all our data

# %%
# a tag contains links for all pages
soupdata.findAll('a',{"class":"ge-49M"})
# Out:
# [<a class="ge-49M _2Kfbh8" href="/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&amp;page=1">1</a>,
#  <a class="ge-49M" href="/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&amp;page=2">2</a>,
#  <a class="ge-49M" href="/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&amp;page=3">3</a>,
#  <a class="ge-49M" href="/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&amp;page=4">4</a>,
#  <a class="ge-49M" href="/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&amp;page=5">5</a>,
#  <a class="ge-49M" href="/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&amp;page=6">6</a>,
#  <a class="ge-49M" href="/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&amp;page=7">7</a>,
#  <a class="ge-49M" href="/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&amp;page=8">8</a>,
#  <a class="ge-49M" href="/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&amp;page=9">9</a>,
#  <a class="ge-49M" href="/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&amp;page=10">10</a>]

# %%
pages_link = soupdata.findAll('a',{"class":"ge-49M"})
pages_link[0].get('href') # this is half link
# Out:
# '/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=1'

# %%
pages_link[1].get('href')# only last link part changes=> page=2
# Out:
# '/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=2'

# %% [markdown]
# #### click on 1st NO then in url u get following text

# %% [raw]
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=1

# %%
pages_link = soupdata.findAll('a',{"class":"ge-49M"})
domain="https://www.flipkart.com"
domain+pages_link[0].get('href')
# Out:
# 'https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=1'

# %%
pages_link = soupdata.findAll('a',{"class":"ge-49M"})
domain="https://www.flipkart.com"

for z in pages_link:
    print(domain+z.get('href'))
# Out:
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=1
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=2
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=3
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=4
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=5
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=6
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=7
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=8
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=9
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=10

# %% [markdown]
# # only page no is changes

# %%
pages_link = soupdata.findAll('a',{"class":"ge-49M"})
domain="https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page="

for z in range(2,21):# as we already done coding for 1st page
    print(domain+str(z))
# Out:
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=1
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=2
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=3
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=4
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=5
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=6
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=7
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=8
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=9
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=10
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=11
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=12
# ...

# %%
httpobject = urlopen("https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g")# this gives response
webdata = httpobject.read() # read http content and save that in variable webdata in binary format
print(webdata)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
httpobject = urlopen("https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=2")# this gives response
webdata2 = httpobject.read() # read http content and save that in variable webdata in binary format
print(webdata2)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
complete_data = webdata + webdata2 # this can't be done ... u can add 2 soup data

# %%
soupdata1=soup(complete_data , 'html.parser')

# %%
containers1 = soupdata1.findAll('div',{'class':'_2kHMtA'})
print(len(containers1))
# Out:
# 48

# %%
f=open('laptop_info_all.csv','wb') # 
f.write('productName,Stars,Ratings,Reviews,CurrentPrice,MRP,Processor,RAM,Storage,ImageURL \n'.encode())
for i in containers1:
    
    product=i.find('div',{'class':'_4rR01T'})
    productName = product.text.split('-')[0].strip() 
   
    star=i.find('div',{'class':'_3LWZlK'})
    try:
        Stars = star.text # storing stars data in Stars var
    except:
        Stars = 0
    
    rating = i.find('span',{'class':'_2_R_DZ'})
    try:
        ratRev = re.findall('\d+,*\d*',rating.text)
        Ratings=ratRev[0].replace(',','')
        Reviews=ratRev[1].replace(',','')
    except:
        Ratings=0
        Reviews=0
    
    CurrentPrice=i.find('div',{'class':'_30jeq3 _1_WHN1'}).text.replace(',','').replace('₹','')
    
    mrp=i.find('div',{'class':'_3I9_wc _27UcVY'}).text
    try:
        MRP = mrp.replace(',','').replace('₹','') # storing 
    except:
        MRP = 0
    
    info=i.findAll('li',{'class':'rgWa7D'})
    a=0
    for j in info[a].text:
        matches = re.findall(r'\d+\s*(?:GB|TB|KB)', info[a].text)
        if len(matches) != 0 :
            Storage = matches[0]
        else :    
            a+=1 
            
    c=0
    for j in info[c].text:
        matches = re.findall(r'\d+\s*(?:GB|TB|KB)', info[c].text)
        if len(matches) != 0 :
            RAM = info[c].text.replace(matches[0],"").strip()
        else :    
            c+=1   
    
            
    b=0   
    for j in info[b].text:
        if "Processor" in info[b].text:
            Processor= info[b].text
        else:
            b+=1
                
    Image=i.img
    ImageURL = Image.get('src')
    
    print(productName,Stars,Ratings,Reviews,CurrentPrice,MRP,Processor,RAM,Storage,ImageURL)
    f.write(f"{productName},{Stars},{Ratings},{Reviews},{CurrentPrice},{MRP},{Processor},{RAM},{Storage},{ImageURL} \n ".encode()) # \n for going to next line in csv file
f.close()
# Out:
# Infinix INBook X2 Plus Core i3 11th Gen 4.1 381 73 28990 44990 Intel Core i3 Processor (11th Gen) LPDDR4X RAM 8 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/n/e/n/-original-imagjfgfjnwnq89g.jpeg?q=70
# HP Ryzen 5 Hexa Core 5500U 4.3 726 83 48990 59109 AMD Ryzen 5 Hexa Core Processor DDR4 RAM 16 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/l/l/u/-original-imagp7pf4hphhyhu.jpeg?q=70
# Primebook 4G Android Based MediaTek MT8788 4 1022 332 16990 24990 MediaTek MediaTek MT8788 Processor LPDDR4 RAM 4 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/i/j/k/-original-imagzzsh3afavghf.jpeg?q=70
# Primebook 4G Android Based MediaTek MT8788 4 1022 332 16990 24990 MediaTek MediaTek MT8788 Processor LPDDR4 RAM 4 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/x/y/s/-original-imagn9s6z2qmxmem.jpeg?q=70
# ...

# %%
df=pd.read_csv(r"laptop_info_all.csv")

# %%
df.shape
# Out:
# (48, 10)

# %% [markdown]
# # combining all

# %%
this takes more time= =>

# %%
httpobject = urlopen("https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g")# this gives response
webdata = httpobject.read()
soupdata = soup(webdata)#convert data into soup data
pages_link = soupdata.findAll('a',{"class":"ge-49M"})
domain="https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page="

for z in range(2,21):# as we already done coding for 1st page
    link = domain+str(z)
    page_data = urlopen(link)
    webdata1 =page_data.read()
    webdata += webdata1 # all data is getting add in webdata1

# %%
soupdata= soup(webdata , 'html.parser')
type(soupdata)
# Out:
# bs4.BeautifulSoup

# %%
containers = soupdata.findAll('div',{'class':'_2kHMtA'})
print(len(containers))
# Out:
# 480

# %%
f=open('laptop_info_all.csv','wb') # 
f.write('productName,Stars,Ratings,Reviews,CurrentPrice,MRP,Processor,RAM,Storage,ImageURL \n'.encode())
for i in containers:
    
    product=i.find('div',{'class':'_4rR01T'})
    productName = product.text.split('-')[0].strip() 
   
    star=i.find('div',{'class':'_3LWZlK'})
    try:
        Stars = star.text # storing stars data in Stars var
    except:
        Stars = 0
    
    rating = i.find('span',{'class':'_2_R_DZ'})
    try:
        ratRev = re.findall('\d+,*\d*',rating.text)
        Ratings=ratRev[0].replace(',','')
        Reviews=ratRev[1].replace(',','')
    except:
        Ratings=0
        Reviews=0
    
    CurrentPrice=i.find('div',{'class':'_30jeq3 _1_WHN1'}).text.replace(',','').replace('₹','')
    
    mrp=i.find('div',{'class':'_3I9_wc _27UcVY'})
    try:
        MRP = mrp.text.replace(',','').replace('₹','') # storing 
    except:
        MRP = 0
    
    info=i.findAll('li',{'class':'rgWa7D'})
    a=0
    for j in info[a].text:
        matches = re.findall(r'\d+\s*(?:GB|TB|KB)', info[a].text)
        if len(matches) != 0 :
            Storage = matches[0]
        else :    
            a+=1 
            
    c=0
    for j in info[c].text:
        matches = re.findall(r'\d+\s*(?:GB|TB|KB)', info[c].text)
        if len(matches) != 0 :
            RAM = info[c].text.replace(matches[0],"").strip()
        else :    
            c+=1   
    
            
    b=0   
    for j in info[b].text:
        if "Processor" in info[b].text:
            Processor= info[b].text
        else:
            b+=1
                
    Image=i.img
    ImageURL = Image.get('src')
    
    print(productName,Stars,Ratings,Reviews,CurrentPrice,MRP,Processor,RAM,Storage,ImageURL)
    f.write(f"{productName},{Stars},{Ratings},{Reviews},{CurrentPrice},{MRP},{Processor},{RAM},{Storage},{ImageURL} \n ".encode()) # \n for going to next line in csv file
f.close()
# Out:
# Primebook 4G Android Based MediaTek MT8788 4 1022 326 16990 24990 MediaTek MediaTek MT8788 Processor LPDDR4 RAM 4 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/i/j/k/-original-imagzzsh3afavghf.jpeg?q=70
# Primebook 4G Android Based MediaTek MT8788 4 1022 326 13990 24990 MediaTek MediaTek MT8788 Processor LPDDR4 RAM 4 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/x/y/s/-original-imagn9s6z2qmxmem.jpeg?q=70
# ASUS Vivobook 15 Core i3 11th Gen 4.2 3171 284 34990 49990 Intel Core i3 Processor (11th Gen) DDR4 RAM 8 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/q/e/z/-original-imagpxgqesgrthks.jpeg?q=70
# HP 15s (2023) Ryzen 3 Dual Core 3250U 4.1 1586 152 29990 39995 AMD Ryzen 3 Dual Core Processor DDR4 RAM 8 GB https://rukminim2.flixcart.com/image/312/312/xif0q/computer/5/6/i/-original-imaggshd5zgfe8ev.jpeg?q=70
# ...

# %%
df=pd.read_csv(r"laptop_info_all.csv" , on_bad_lines = 'warn')
# Out:
# Skipping line 215: expected 10 fields, saw 12
# Skipping line 376: expected 10 fields, saw 11

# %%
df.shape #  :) done extracted 478 out of 480
# Out:
# (478, 10)

# %%
less time =>

# %%
httpobject = urlopen("https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g")# this gives response
first_page = httpobject.read() # read http content and save that in variable webdata in binary format
first_page_soup = soup(first_page)

# %%
all_links = soupdata.findAll('a',{"class":"ge-49M"})
single_link="https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page="

for z in range(2,21):# as we already done coding for 1st page
    link = single_link +str(z)
    print(link)
# Out:
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=2
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=3
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=4
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=5
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=6
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=7
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=8
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=9
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=10
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=11
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=12
# https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g&page=13
# ...
